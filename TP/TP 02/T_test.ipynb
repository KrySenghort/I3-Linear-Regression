# %%
library(gapminder)
library(tidyverse)
View(gapminder)
# Out:
#      country     continent year lifeExp pop      gdpPercap
# 1    Afghanistan Asia      1952 28.801   8425333  779.4453
# 2    Afghanistan Asia      1957 30.332   9240934  820.8530
# 3    Afghanistan Asia      1962 31.997  10267083  853.1007
# 4    Afghanistan Asia      1967 34.020  11537966  836.1971
# 5    Afghanistan Asia      1972 36.088  13079460  739.9811
# 6    Afghanistan Asia      1977 38.438  14880372  786.1134
# 7    Afghanistan Asia      1982 39.854  12881816  978.0114
# 8    Afghanistan Asia      1987 40.822  13867957  852.3959
# 9    Afghanistan Asia      1992 41.674  16317921  649.3414
# 10   Afghanistan Asia      1997 41.763  22227415  635.3414
# 11   Afghanistan Asia      2002 42.129  25268405  726.7341
# 12   Afghanistan Asia      2007 43.828  31889923  974.5803
# 13   Albania     Europe    1952 55.230   1282697 1601.0561
# 14   Albania     Europe    1957 59.280   1476505 1942.2842
# 15   Albania     Europe    1962 64.820   1728137 2312.8890
# ...

# %% [markdown]
# #### <font color = blue><b>1.1 Exploratory Data Analysis
# ##### <font color = yellow>1.1.1 Displaying data

# %%
gapminder
# Out:
#      country     continent year lifeExp pop      gdpPercap
# 1    Afghanistan Asia      1952 28.801   8425333  779.4453
# 2    Afghanistan Asia      1957 30.332   9240934  820.8530
# 3    Afghanistan Asia      1962 31.997  10267083  853.1007
# 4    Afghanistan Asia      1967 34.020  11537966  836.1971
# 5    Afghanistan Asia      1972 36.088  13079460  739.9811
# 6    Afghanistan Asia      1977 38.438  14880372  786.1134
# 7    Afghanistan Asia      1982 39.854  12881816  978.0114
# 8    Afghanistan Asia      1987 40.822  13867957  852.3959
# 9    Afghanistan Asia      1992 41.674  16317921  649.3414
# 10   Afghanistan Asia      1997 41.763  22227415  635.3414
# 11   Afghanistan Asia      2002 42.129  25268405  726.7341
# 12   Afghanistan Asia      2007 43.828  31889923  974.5803
# 13   Albania     Europe    1952 55.230   1282697 1601.0561
# 14   Albania     Europe    1957 59.280   1476505 1942.2842
# 15   Albania     Europe    1962 64.820   1728137 2312.8890
# ...

# %% [markdown]
# #### <font color = yellow>1.1.2 Data description

# %%
summary(gapminder)
# Out:
#         country        continent        year         lifeExp
#  Afghanistan:  12   Africa  :624   Min.   :1952   Min.   :23.60
#  Albania    :  12   Americas:300   1st Qu.:1966   1st Qu.:48.20
#  Algeria    :  12   Asia    :396   Median :1980   Median :60.71
#  Angola     :  12   Europe  :360   Mean   :1980   Mean   :59.47
#  Argentina  :  12   Oceania : 24   3rd Qu.:1993   3rd Qu.:70.85
#  Australia  :  12                  Max.   :2007   Max.   :82.60
#  (Other)    :1632
#       pop              gdpPercap
#  Min.   :6.001e+04   Min.   :   241.2
#  1st Qu.:2.794e+06   1st Qu.:  1202.1
#  Median :7.024e+06   Median :  3531.8
#  Mean   :2.960e+07   Mean   :  7215.3
#  3rd Qu.:1.959e+07   3rd Qu.:  9325.5
#  Max.   :1.319e+09   Max.   :113523.1

# %%
library('psych')
psych::describe(gapminder)
# Out:
#            vars n    mean         sd           median       trimmed
# country*   1    1704 7.150000e+01 4.100289e+01      71.5000 7.150000e+01
# continent* 2    1704 2.330986e+00 1.209020e+00       2.0000 2.271261e+00
# year       3    1704 1.979500e+03 1.726533e+01    1979.5000 1.979500e+03
# lifeExp    4    1704 5.947444e+01 1.291711e+01      60.7125 5.991524e+01
# pop        5    1704 2.960121e+07 1.061579e+08 7023595.5000 1.139946e+07
# gdpPercap  6    1704 7.215327e+03 9.857455e+03    3531.8470 5.221443e+03
#            mad          min        max          range        skew
# country*   5.263230e+01     1.0000 1.420000e+02 1.410000e+02  0.0000000
# continent* 1.482600e+00     1.0000 5.000000e+00 4.000000e+00  0.2545052
# year       2.223900e+01  1952.0000 2.007000e+03 5.500000e+01  0.0000000
# lifeExp    1.610104e+01    23.5990 8.260300e+01 5.900400e+01 -0.2522575
# pop        7.841474e+06 60011.0000 1.318683e+09 1.318623e+09  8.3255400
# ...

# %% [markdown]
# #### <font color=yellow>1.1.3. Graph Visualization

# %% [markdown]
# <b><font color=blue> population histogram

# %%
ggplot(gapminder,aes(pop)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# <b><font color = blue>Pair plot

# %%
pairs(gapminder[,3:6])
# Out:
# plot without title

# %%
pairs(gapminder)
# Out:
# plot without title

# %%
cor(gapminder[, 3:6])
# Out:
#           year       lifeExp    pop         gdpPercap
# year      1.00000000 0.43561122  0.08230808  0.22731807
# lifeExp   0.43561122 1.00000000  0.06495537  0.58370622
# pop       0.08230808 0.06495537  1.00000000 -0.02559958
# gdpPercap 0.22731807 0.58370622 -0.02559958  1.00000000

# %%
# install.packages("broom")
CorMatrix <- broom::tidy(cor(gapminder[, 3:6])) %>%  rename(Var1 = ".rownames") %>% gather(Var2, Cor, -Var1)
print(CorMatrix)
# Out:
# Warning message:
# "'tidy.numeric' is deprecated.
# See help("Deprecated")"
# Error in `rename()`:
# ! Can't rename columns that don't exist.
# ✖ Column `.rownames` doesn't exist.
# Traceback:
#
# 1. broom::tidy(cor(gapminder[, 3:6])) %>% rename(Var1 = ".rownames") %>%
#  .     gather(Var2, Cor, -Var1)
# 2. gather(., Var2, Cor, -Var1)
# 3. rename(., Var1 = ".rownames")
# 4. rename.data.frame(., Var1 = ".rownames")
# 5. tidyselect::eval_rename(expr(c(...)), .data)
# 6. rename_impl(data, names(data), as_quosure(expr, env), strict = strict,
#  .     name_spec = name_spec, allow_predicates = allow_predicates,
#  .     error_call = error_call)
# 7. eval_select_impl(x, names, {
#  .     {
#  .         sel
#  .     }
#  . }, strict = strict, name_spec = name_spec, type = "rename", allow_predicates = allow_predicates,
#  .     error_call = error_call)
# 8. with_subscript_errors(out <- vars_select_eval(vars, expr, strict = strict,
# ...

# %%
ggplot(CorMatrix, aes(Var1, Var2, fill = Cor)) +
  geom_tile()
# Out:
# Error in ggplot(CorMatrix, aes(Var1, Var2, fill = Cor)): object 'CorMatrix' not found
# Traceback:
#
# 1. ggplot(CorMatrix, aes(Var1, Var2, fill = Cor))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
gapminder %>% 
  filter(continent=="Africa") %>% 
  select(lifeExp) %>% 
  t.test(mu=50)

my_ttest <- gapminder %>% 
  filter(continent=="Africa") %>% 
  select(lifeExp) %>% 
  t.test(mu=50)

attributes(my_ttest)
my_ttest$p.value
# Out:
# 	One Sample t-test
#
# data:  .
# t = -3.0976, df = 623, p-value = 0.002038
# alternative hypothesis: true mean is not equal to 50
# 95 percent confidence interval:
#  48.14599 49.58467
# sample estimates:
# mean of x
#  48.86533
# $names
#  [1] "statistic"   "parameter"   "p.value"     "conf.int"    "estimate"
#  [6] "null.value"  "stderr"      "alternative" "method"      "data.name"
#
# $class
# [1] "htest"
# [1] 0.002038444

# %%
library(tidyverse)
my_data <- starwars %>% select(sex,height) %>% filter(sex %in% c("male","female")) %>% drop_na(height)
my_data
# Out:
#    sex    height
# 1  male   172
# 2  male   202
# 3  female 150
# 4  male   178
# 5  female 165
# 6  male   183
# 7  male   182
# 8  male   188
# 9  male   180
# 10 male   228
# 11 male   180
# 12 male   173
# 13 male   170
# 14 male   180
# 15 male    66
# 16 male   170
# 17 male   183
# 18 male   190
# 19 male   177
# 20 male   175
# 21 male   180
# 22 female 150
# 23 male    88
# 24 male   160
# 25 male   193
# 26 male   191
# 27 male   170
# 28 male   196
# 29 male   224
# 30 male   206
# ⋮  ⋮      ⋮
# 43 male   171
# 44 female 184
# 45 male   188
# 46 male   264
# 47 male   188
# 48 male   196
# 49 male   185
# 50 female 157
# 51 male   183
# 52 male   183
# 53 female 170
# 54 female 166
# 55 female 165
# 56 male   193
# 57 male   191
# 58 male   183
# 59 female 168
# 60 male   198
# 61 male   229
# 62 female 213
# 63 female 167
# 64 male    79
# 65 male   193
# 66 male   191
# 67 female 178
# 68 male   216
# 69 male   234
# 70 male   188
# 71 male   206
# 72 female 165

# %%
t.test(height ~ sex,data=my_data)
# Out:
# 	Welch Two Sample t-test
#
# data:  height by sex
# t = -1.5876, df = 55.148, p-value = 0.1181
# alternative hypothesis: true difference in means between group female and group male is not equal to 0
# 95 percent confidence interval:
#  -22.256861   2.579668
# sample estimates:
# mean in group female   mean in group male
#             169.2667             179.1053

# %%
starwars %>% select(sex,height) %>% filter(sex %in% c("male","female")) %>% drop_na(height) %>% t.test(height ~ sex, data=.)
# Out:
# 	Welch Two Sample t-test
#
# data:  height by sex
# t = -1.5876, df = 55.148, p-value = 0.1181
# alternative hypothesis: true difference in means between group female and group male is not equal to 0
# 95 percent confidence interval:
#  -22.256861   2.579668
# sample estimates:
# mean in group female   mean in group male
#             169.2667             179.1053

# %%
t.test(height ~ sex, 
       data = my_data, 
       alternative = two.sided, 
       mu=0,paired=FALSE, 
       var.equal = FALSE, 
       conf.level = 0.95)
# Out:
# Error in match.arg(alternative): object 'two.sided' not found
# Traceback:
#
# 1. t.test(height ~ sex, data = my_data, alternative = two.sided,
#  .     mu = 0, paired = FALSE, var.equal = FALSE, conf.level = 0.95)
# 2. t.test.formula(height ~ sex, data = my_data, alternative = two.sided,
#  .     mu = 0, paired = FALSE, var.equal = FALSE, conf.level = 0.95)
# 3. t.test(x = DATA[[1L]], y = DATA[[2L]], ...)
# 4. t.test.default(x = DATA[[1L]], y = DATA[[2L]], ...)
# 5. match.arg(alternative)
