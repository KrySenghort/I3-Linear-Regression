# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
library(alr4)
library(tidyverse)
data(Htwt)
Htwt
# Out:
#    ht    wt
# 1  169.6 71.2
# 2  166.8 58.2
# 3  157.1 56.0
# 4  181.1 64.5
# 5  158.4 53.0
# 6  165.6 52.4
# 7  166.7 56.8
# 8  156.5 49.2
# 9  168.1 55.6
# 10 165.3 77.8

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plot(log(Htwt$ht)~log(Htwt$wt),main='Regression between height Vs weight',xlab = 'height',ylab= 'weight')
# Out:
# Plot with title "Regression between height Vs weight"

# %% [markdown]
# Base on the scatterplot above, we observe that, the data point state at the different points and has distance so far between them.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
b1 <- sum((Htwt$ht-mean(Htwt$ht))*(Htwt$wt-mean(Htwt$wt)))/(sum((Htwt$ht-mean(Htwt$ht))**2)) 
b1
# Out:
# [1] 0.58208

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
b0 = mean(Htwt$wt)-b1*mean(Htwt$ht)
b0
# Out:
# [1] -36.87588

# %% [markdown]
# $ So $ $ we $ $ have $ $ the $ $ equation $ $ is $ $ denoted $ $ by: $ $ y $ $ = $ $ 0.582080004067142x - 36.8758822731934 $

# %%
plot(Htwt$ht,Htwt$wt,main='Regression between height Vs weight',xlab = 'height',ylab= 'weight')
abline(lm(wt~ht,data = Htwt),col='red')
# Out:
# Plot with title "Regression between height Vs weight"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Htwt %>% select(ht) %>% select(wt) %>% t.test(mu=mean(ht),mu=mean(wt))
x <- Htwt %>% select(ht) %>% select(wt) %>% t.test(mu=mean(ht),mu=mean(wt))
attributes(x)
x$p.value
# Out:
# Error in `select()`:
# ! Can't subset columns that don't exist.
# ✖ Column `wt` doesn't exist.
# Traceback:
#
# 1. Htwt %>% select(ht) %>% select(wt) %>% t.test(mu = mean(ht),
#  .     mu = mean(wt))
# 2. t.test(., mu = mean(ht), mu = mean(wt))
# 3. select(., wt)
# 4. select.data.frame(., wt)
# 5. tidyselect::eval_select(expr(c(...)), data = .data, error_call = error_call)
# 6. eval_select_impl(data, names(data), as_quosure(expr, env), include = include,
#  .     exclude = exclude, strict = strict, name_spec = name_spec,
#  .     allow_rename = allow_rename, allow_empty = allow_empty, allow_predicates = allow_predicates,
#  .     error_call = error_call, )
# 7. with_subscript_errors(out <- vars_select_eval(vars, expr, strict = strict,
#  .     data = x, name_spec = name_spec, uniquely_named = uniquely_named,
#  .     allow_rename = allow_rename, allow_empty = allow_empty, allow_predicates = allow_predicates,
#  .     type = type, error_call = error_call), type = type)
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
